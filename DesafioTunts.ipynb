# %%
import pandas as pd
import numpy as np
conda install xldr
conda install openpyxl

# %%
df = pd.read_excel (r'C:\Users\preci\Desktop\DesafioTunts.xlsx')

# %%
df
# Out:
#    Engenharia de Software Desafio AUGUSTO LUZZI   Unnamed: 1 Unnamed: 2  \
# 0                Total de aulas no semestre: 60          NaN        NaN
# 1                                     Matricula        Aluno     Faltas
# 2                                             1      Eduardo          8
# 3                                             2       Murilo          8
# 4                                             3    Guilherme         19
# 5                                             4       Flavia         23
# 6                                             5         Ruan         13
# 7                                             6      Arnando         23
# 8                                             7        Lucas          5
# 9                                             8        Fabio         10
# 10                                            9      Alisson         15
# 11                                           10       Felipe         12
# ...

# %%
df_approved =  df.copy().drop(1)

df_approved
# Out:
#    Engenharia de Software Desafio AUGUSTO LUZZI   Unnamed: 1 Unnamed: 2  \
# 0                Total de aulas no semestre: 60          NaN        NaN
# 2                                             1      Eduardo          8
# 3                                             2       Murilo          8
# 4                                             3    Guilherme         19
# 5                                             4       Flavia         23
# 6                                             5         Ruan         13
# 7                                             6      Arnando         23
# 8                                             7        Lucas          5
# 9                                             8        Fabio         10
# 10                                            9      Alisson         15
# 11                                           10       Felipe         12
# 12                                           11       Rachel         11
# ...

# %%
df_approved["Final Mean"] = (df_approved['Unnamed: 3'] + df_approved['Unnamed: 4'] + df_approved['Unnamed: 5'])/3

# %%
df_approved["Final Mean"] = pd.to_numeric(df_approved["Final Mean"])

# %%
df_approved.loc[df_approved['Final Mean'] <50, 'Unnamed: 6'] =  'Reprovado'
df_approved.loc[df_approved['Final Mean'] > 'Unnamed: 6'] =  'Reprovado'

# %%
df_approved
# Out:
#    Engenharia de Software Desafio AUGUSTO LUZZI   Unnamed: 1 Unnamed: 2  \
# 0                Total de aulas no semestre: 60          NaN        NaN
# 2                                             1      Eduardo          8
# 3                                             2       Murilo          8
# 4                                             3    Guilherme         19
# 5                                             4       Flavia         23
# 6                                             5         Ruan         13
# 7                                             6      Arnando         23
# 8                                             7        Lucas          5
# 9                                             8        Fabio         10
# 10                                            9      Alisson         15
# 11                                           10       Felipe         12
# 12                                           11       Rachel         11
# ...

# %%
df_approved.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Engenharia de Software Desafio AUGUSTO LUZZI  25 non-null     object
#  1   Unnamed: 1                                    24 non-null     object
#  2   Unnamed: 2                                    24 non-null     object
#  3   Unnamed: 3                                    24 non-null     object
#  4   Unnamed: 4                                    24 non-null     object
#  5   Unnamed: 5                                    24 non-null     object
#  6   Unnamed: 6                                    0 non-null      object
#  7   Unnamed: 7                                    0 non-null      object
#  8   Final Mean                                    24 non-null     object
# dtypes: object(9)
# memory usage: 2.0+ KB

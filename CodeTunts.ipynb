# %%
#Import packages 
import pandas as pd
import numpy as np
import math
conda install xldr
conda install openpyxl

# %%
#Download the excel file to your desktop and put the right path
df = pd.read_excel (r'C:\Users\Your_User\Desktop\File_name.xlsx')

# %%
df = df.rename(columns={'Unnamed: 1': 'Nome'})
df = df.rename(columns={'Unnamed: 2': 'Faltas'})
df = df.rename(columns={'Unnamed: 3': 'P1'})
df = df.rename(columns={'Unnamed: 4': 'P2'})
df = df.rename(columns={'Unnamed: 5': 'P3'})
df = df.rename(columns={'Unnamed: 6': 'Situação'})
df = df.rename(columns={'Unnamed: 7': 'NAF'})

df.drop(1)
# Out:
#    Engenharia de Software Desafio AUGUSTO LUZZI         Nome Faltas   P1   P2  \
# 0                Total de aulas no semestre: 60          NaN    NaN  NaN  NaN
# 2                                             1      Eduardo      8   35   63
# 3                                             2       Murilo      8   64   97
# 4                                             3    Guilherme     19   68   74
# 5                                             4       Flavia     23   66   98
# 6                                             5         Ruan     13   80   65
# 7                                             6      Arnando     23   83   68
# 8                                             7        Lucas      5   38   53
# 9                                             8        Fabio     10   53   96
# 10                                            9      Alisson     15   45   61
# 11                                           10       Felipe     12   32   41
# 12                                           11       Rachel     11   84   66
# 13                                           12         Jouy     13   42   93
# 14                                           13     François     19   59   87
# 15                                           14      Dâmaris     10   44   50
# 16                                           15     Leonardo     16   83   92
# 17                                           16    Guilherme      6   36   38
# 18                                           17       Wesley     16   41   52
# 19                                           18         Yuri      2   87   75
# 20                                           19         Kira      8   36   46
# 21                                           20       Cleici     22   91   88
# 22                                           21  João Moacir     23   38   90
# 23                                           22        Bruno     15   96   37
# 24                                           23        Elcio      9   73   71
# 25                                           24      Criscia      0   50   95
#
#      P3 Situação  NAF
# 0   NaN      NaN  NaN
# 2    61      NaN  NaN
# 3    36      NaN  NaN
# 4    51      NaN  NaN
# 5    62      NaN  NaN
# 6    41      NaN  NaN
# 7    77      NaN  NaN
# 8    80      NaN  NaN
# 9    89      NaN  NaN
# 10   68      NaN  NaN
# 11   85      NaN  NaN
# 12   39      NaN  NaN
# 13   57      NaN  NaN
# 14   89      NaN  NaN
# 15   62      NaN  NaN
# 16   32      NaN  NaN
# 17   76      NaN  NaN
# 18   87      NaN  NaN
# 19   50      NaN  NaN
# 20   48      NaN  NaN
# 21   92      NaN  NaN
# 22   98      NaN  NaN
# 23  100      NaN  NaN
# 24   75      NaN  NaN
# 25   84      NaN  NaN

# %%
df_approved =  df.copy().drop(1)
df_approved["P1"] = pd.to_numeric(df_approved["P1"])
df_approved["P2"] = pd.to_numeric(df_approved["P2"])
df_approved["P3"] = pd.to_numeric(df_approved["P3"])

# %%
df_approved["Media Final"] = np.ceil((df_approved['P1'] + df_approved['P2'] + df_approved['P3'])/3)

# %%
df_approved["Media Final"] = pd.to_numeric(df_approved["Media Final"])

# %%
df_approved.loc[df_approved['Media Final'] <50, 'Situação'] =  'Reprovado por Nota'
df_approved.loc[df_approved['Media Final'] <70 , 'Situação'] =  'Exame Final'
df_approved.loc[df_approved['Media Final'] >=70, 'Situação'] =  'Aprovado'

df_approved.loc[df_approved['Media Final'] <50, 'NAF'] =  '0'
df_approved.loc[df_approved['Media Final'] >=70, 'NAF'] = '0'
df_approved.loc[df_approved['Media Final'] <70, 'NAF'] = np.ceil(100 - df_approved['Media Final'])

df_approved.loc[df_approved['Faltas'] >15, 'Situação'] =  'Reprovado por Falta'

# %%
df_approved
# Out:
#    Engenharia de Software Desafio AUGUSTO LUZZI         Nome Faltas    P1  \
# 0                Total de aulas no semestre: 60          NaN    NaN   NaN
# 2                                             1      Eduardo      8  35.0
# 3                                             2       Murilo      8  64.0
# 4                                             3    Guilherme     19  68.0
# 5                                             4       Flavia     23  66.0
# 6                                             5         Ruan     13  80.0
# 7                                             6      Arnando     23  83.0
# 8                                             7        Lucas      5  38.0
# 9                                             8        Fabio     10  53.0
# 10                                            9      Alisson     15  45.0
# 11                                           10       Felipe     12  32.0
# 12                                           11       Rachel     11  84.0
# 13                                           12         Jouy     13  42.0
# 14                                           13     François     19  59.0
# 15                                           14      Dâmaris     10  44.0
# 16                                           15     Leonardo     16  83.0
# 17                                           16    Guilherme      6  36.0
# 18                                           17       Wesley     16  41.0
# 19                                           18         Yuri      2  87.0
# 20                                           19         Kira      8  36.0
# 21                                           20       Cleici     22  91.0
# 22                                           21  João Moacir     23  38.0
# 23                                           22        Bruno     15  96.0
# 24                                           23        Elcio      9  73.0
# 25                                           24      Criscia      0  50.0
#
#       P2     P3             Situação   NAF  Media Final
# 0    NaN    NaN                  NaN   NaN          NaN
# 2   63.0   61.0          Exame Final  47.0         53.0
# 3   97.0   36.0          Exame Final  34.0         66.0
# 4   74.0   51.0  Reprovado por Falta  35.0         65.0
# 5   98.0   62.0  Reprovado por Falta     0         76.0
# 6   65.0   41.0          Exame Final  38.0         62.0
# 7   68.0   77.0  Reprovado por Falta     0         76.0
# 8   53.0   80.0          Exame Final  43.0         57.0
# 9   96.0   89.0             Aprovado     0         80.0
# 10  61.0   68.0          Exame Final  42.0         58.0
# 11  41.0   85.0          Exame Final  47.0         53.0
# 12  66.0   39.0          Exame Final  37.0         63.0
# 13  93.0   57.0          Exame Final  36.0         64.0
# 14  87.0   89.0  Reprovado por Falta     0         79.0
# 15  50.0   62.0          Exame Final  48.0         52.0
# 16  92.0   32.0  Reprovado por Falta  31.0         69.0
# 17  38.0   76.0          Exame Final  50.0         50.0
# 18  52.0   87.0  Reprovado por Falta  40.0         60.0
# 19  75.0   50.0             Aprovado     0         71.0
# 20  46.0   48.0          Exame Final  56.0         44.0
# 21  88.0   92.0  Reprovado por Falta     0         91.0
# 22  90.0   98.0  Reprovado por Falta     0         76.0
# 23  37.0  100.0             Aprovado     0         78.0
# 24  71.0   75.0             Aprovado     0         73.0
# 25  95.0   84.0             Aprovado     0         77.0
